# %%
import sys

ROOT_DIR = '../'
sys.path.append(ROOT_DIR)

import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from src.datasets import get_cifar, get_adversarial_cifar

# %%
cifar_root = '/home/sutter/.torch/'

cifar = get_cifar(cifar_root, batch_size=4, split='train')
cifar_aug = get_cifar(cifar_root, batch_size=4, split='train', augmentation=True)
adv_cifar = get_adversarial_cifar(cifar_root, batch_size=4)
adv_cifar_noise = get_adversarial_cifar(cifar_root, zero_out_ratio=0.1, batch_size=4)

# %% [markdown]
# (images will look horrible because they are normalized...)

# %%
# Creating iterators just to sample easily
cifar_iter = iter(cifar)
cifar_aug_iter = iter(cifar_aug)
adv_cifar_iter = iter(adv_cifar)
adv_cifar_noise_iter = iter(adv_cifar_noise)

cifar_sample = next(cifar_iter)
cifar_aug_sample = next(cifar_aug_iter)
adv_cifar_sample = next(adv_cifar_iter)
adv_cifar_noise_sample = next(adv_cifar_noise_iter)

# %%
plt.subplot(121)
plt.imshow(cifar_sample[0][0])

plt.subplot(122)
plt.imshow(adv_cifar_sample[0][0])

print(cifar_sample[1][0].item(), adv_cifar_sample[1][0].item())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6 5

# %%
plt.subplot(121)
plt.imshow(cifar_sample[0][0])

plt.subplot(122)
plt.imshow(cifar_aug_sample[0][0])

print(cifar_sample[1][0].item(), cifar_aug_sample[1][0].item())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6 6

# %%
plt.subplot(121)
plt.imshow(cifar_sample[0][0])

plt.subplot(122)
plt.imshow(adv_cifar_noise_sample[0][0])

print(cifar_sample[1][0].item(), adv_cifar_noise_sample[1][0].item())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6 5
