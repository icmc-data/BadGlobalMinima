# %%
import sys

ROOT_DIR = '../'
sys.path.append(ROOT_DIR)

import numpy as np
import matplotlib.pyplot as plt

from src.datasets import get_cifar, get_adversarial_cifar

# %%
cifar_root = '/home/sutter/.torch/'

cifar = get_cifar(cifar_root, split='train')
cifar_aug = get_cifar(cifar_root, split='train', augmentation=True)
adv_cifar = get_adversarial_cifar(cifar_root)
adv_cifar_noise = get_adversarial_cifar(cifar_root, zero_out_ratio=0.1)

# %% [markdown]
# (images will look horrible because they are normalized...)

# %%
plt.subplot(121)
plt.imshow(np.transpose(cifar[0][0], [1, 2, 0]))

plt.subplot(122)
plt.imshow(np.transpose(adv_cifar[0][0], [1, 2, 0]))

print(cifar[0][1], adv_cifar[0][1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6 5

# %%
plt.subplot(121)
plt.imshow(np.transpose(cifar[0][0], [1, 2, 0]))

plt.subplot(122)
plt.imshow(np.transpose(cifar_aug[0][0], [1, 2, 0]))

print(cifar[0][1], adv_cifar[0][1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6 5

# %%
plt.subplot(121)
plt.imshow(np.transpose(cifar[0][0], [1, 2, 0]))

plt.subplot(122)
plt.imshow(np.transpose(adv_cifar_noise[0][0], [1, 2, 0]))

print(cifar[0][1], adv_cifar[0][1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 6 5
